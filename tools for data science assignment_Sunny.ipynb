# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# Sunny, LIN.   My desired occupation is data analyst.

# %% [markdown]
# I am interested in data science because I know we can do lots of things by the power of data. And I think data is the future.

# %% [markdown]
# My code in Cell 5 will be merely simple math calculation.

# %%
r=1
total=r+r
print(total)
# Out:
# 2

# %% [markdown]
# - one
# - two
# - three
